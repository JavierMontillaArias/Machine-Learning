# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#Dataframe = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
#Import data
car_sales = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")

# %%
exported_car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)    float64
# Doors            float64
# Price            float64
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    131253.237895
# Doors                 4.011579
# Price             16042.814737
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean(numeric_only=True)
# Out:
# np.float64(38583.333333333336)

# %%
car_sales["Doors"].sum()
# Out:
# np.float64(3811.0)

# %%
len(car_sales)
# Out:
# 1000

# %% [markdown]
# ## Viewing and selenting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0
# 5   Honda    Red        42652.0    4.0  23883.0
# 6  Toyota   Blue       163453.0    4.0   8473.0

# %%
car_sales.tail()
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0

# %%
# .loc & refers to index
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index = [0, 3, 9, 8, 3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make               Toyota
# Colour              White
# Odometer (KM)    154365.0
# Doors                 4.0
# Price             13434.0
# Name: 3, dtype: object

# %%
#.iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make               Toyota
# Colour              White
# Odometer (KM)    154365.0
# Doors                 4.0
# Price             13434.0
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0

# %%
car_sales["Make"]
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996       NaN
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0      White
# 1       Blue
# 2      White
# 3      White
# 4       Blue
#        ...
# 995    Black
# 996    White
# 997     Blue
# 998    White
# 999     Blue
# Name: Colour, Length: 1000, dtype: object

# %%
car_sales.Make
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996       NaN
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 3    Toyota  White       154365.0    4.0  13434.0
# 6    Toyota   Blue       163453.0    4.0   8473.0
# 15   Toyota   Blue       205592.0    4.0  16290.0
# 16   Toyota    Red        96742.0    4.0  34465.0
# 20   Toyota    NaN       124844.0    4.0  24130.0
# ..      ...    ...            ...    ...      ...
# 983  Toyota    Red            NaN    4.0  14671.0
# 989  Toyota    Red        41735.0    4.0  13928.0
# 990  Toyota  White       173408.0    4.0   8082.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [379 rows x 5 columns]

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 1       BMW   Blue       192714.0    5.0  19943.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# 6    Toyota   Blue       163453.0    4.0   8473.0
# 8       NaN  White       130538.0    4.0   9374.0
# ..      ...    ...            ...    ...      ...
# 993  Nissan  Black       162523.0    4.0   4696.0
# 994     BMW   Blue       163322.0    3.0  31666.0
# 996     NaN  White       155144.0    3.0   5716.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [597 rows x 5 columns]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3.0  4.0  5.0
# Make
# BMW      21    0   72
# Honda     0  276    0
# Nissan   38  137    0
# Toyota    0  359    0

# %%
# Groupby
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)     Doors         Price
# Make
# BMW     127491.439560  4.548387  26902.440860
# Honda   125233.374101  4.000000  14618.661922
# Nissan  136809.029070  3.782857  13664.502857
# Toyota  135942.582873  4.000000  15715.257062

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulate Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996       NaN
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     honda  White        35431.0    4.0  15323.0
# 1       bmw   Blue       192714.0    5.0  19943.0
# 2     honda  White        84714.0    4.0  28343.0
# 3    toyota  White       154365.0    4.0  13434.0
# 4    nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  nissan   Blue        66604.0    4.0  31570.0
# 998   honda  White       215883.0    4.0   4001.0
# 999  toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean())
# Out:
# 0       35431.0
# 1      192714.0
# 2       84714.0
# 3      154365.0
# 4      181577.0
#          ...
# 995     35820.0
# 996    155144.0
# 997     66604.0
# 998    215883.0
# 999    248360.0
# Name: Odometer (KM), Length: 1000, dtype: float64

# %%
car_sales_missing["Odometer (KM)"] = car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean())

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [773 rows x 5 columns]

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     honda  White        35431.0    4.0  15323.0    5.0
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0
# 2     honda  White        84714.0    4.0  28343.0    5.0
# 3    toyota  White       154365.0    4.0  13434.0    5.0
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 995  toyota  Black        35820.0    4.0  32042.0    NaN
# 996     NaN  White       155144.0    3.0   5716.0    NaN
# 997  nissan   Blue        66604.0    4.0  31570.0    NaN
# 998   honda  White       215883.0    4.0   4001.0    NaN
# 999  toyota   Blue       248360.0    4.0  12732.0    NaN
#
# [1000 rows x 6 columns]

# %%
car_sales["Seats"] = car_sales["Seats"].fillna(5)
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     honda  White        35431.0    4.0  15323.0    5.0
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0
# 2     honda  White        84714.0    4.0  28343.0    5.0
# 3    toyota  White       154365.0    4.0  13434.0    5.0
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0
# ..      ...    ...            ...    ...      ...    ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0
# 996     NaN  White       155144.0    3.0   5716.0    5.0
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0
# 998   honda  White       215883.0    4.0   4001.0    5.0
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0
#
# [1000 rows x 6 columns]

# %%
# Column from Python list
import numpy as np
fuel_economy = np.random.uniform(5, 10, 1000).tolist()
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0     honda  White        35431.0    4.0  15323.0    5.0        6.105188
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0        9.314392
# 2     honda  White        84714.0    4.0  28343.0    5.0        7.549864
# 3    toyota  White       154365.0    4.0  13434.0    5.0        5.778420
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0        6.412303
# ..      ...    ...            ...    ...      ...    ...             ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0        8.415605
# 996     NaN  White       155144.0    3.0   5716.0    5.0        5.955185
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0        8.494556
# 998   honda  White       215883.0    4.0   4001.0    5.0        9.986542
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0        8.039036
#
# [1000 rows x 7 columns]

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 *car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     honda  White        35431.0    4.0  15323.0    5.0        6.105188
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0        9.314392
# 2     honda  White        84714.0    4.0  28343.0    5.0        7.549864
# 3    toyota  White       154365.0    4.0  13434.0    5.0        5.778420
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0        6.412303
# ..      ...    ...            ...    ...      ...    ...             ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0        8.415605
# 996     NaN  White       155144.0    3.0   5716.0    5.0        5.955185
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0        8.494556
# 998   honda  White       215883.0    4.0   4001.0    5.0        9.986542
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0        8.039036
#
#      Total fuel used  Total fuel used (L)
# 0        2163.128989          2163.128989
# 1       17950.137271         17950.137271
# 2        6395.791422          6395.791422
# 3        8919.858415          8919.858415
# 4       11643.267692         11643.267692
# ..               ...                  ...
# 995      3014.469748          3014.469748
# 996      9239.112173          9239.112173
# 997      5657.713869          5657.713869
# 998     21559.246862         21559.246862
# 999     19965.750017         19965.750017
#
# [1000 rows x 9 columns]

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     honda  White        35431.0    4.0  15323.0    5.0        6.105188
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0        9.314392
# 2     honda  White        84714.0    4.0  28343.0    5.0        7.549864
# 3    toyota  White       154365.0    4.0  13434.0    5.0        5.778420
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0        6.412303
# ..      ...    ...            ...    ...      ...    ...             ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0        8.415605
# 996     NaN  White       155144.0    3.0   5716.0    5.0        5.955185
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0        8.494556
# 998   honda  White       215883.0    4.0   4001.0    5.0        9.986542
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0        8.039036
#
#      Total fuel used  Total fuel used (L)  Number of wheels
# 0        2163.128989          2163.128989                 4
# 1       17950.137271         17950.137271                 4
# 2        6395.791422          6395.791422                 4
# 3        8919.858415          8919.858415                 4
# 4       11643.267692         11643.267692                 4
# ..               ...                  ...               ...
# 995      3014.469748          3014.469748                 4
# 996      9239.112173          9239.112173                 4
# 997      5657.713869          5657.713869                 4
# 998     21559.246862         21559.246862                 4
# 999     19965.750017         19965.750017                 4
#
# [1000 rows x 10 columns]

# %%
car_sales["Passed road safety"] = True

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     honda  White        35431.0    4.0  15323.0    5.0        6.105188
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0        9.314392
# 2     honda  White        84714.0    4.0  28343.0    5.0        7.549864
# 3    toyota  White       154365.0    4.0  13434.0    5.0        5.778420
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0        6.412303
# ..      ...    ...            ...    ...      ...    ...             ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0        8.415605
# 996     NaN  White       155144.0    3.0   5716.0    5.0        5.955185
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0        8.494556
# 998   honda  White       215883.0    4.0   4001.0    5.0        9.986542
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0        8.039036
#
#      Total fuel used  Total fuel used (L)  Number of wheels  \
# 0        2163.128989          2163.128989                 4
# 1       17950.137271         17950.137271                 4
# 2        6395.791422          6395.791422                 4
# 3        8919.858415          8919.858415                 4
# 4       11643.267692         11643.267692                 4
# ..               ...                  ...               ...
# 995      3014.469748          3014.469748                 4
# 996      9239.112173          9239.112173                 4
# 997      5657.713869          5657.713869                 4
# 998     21559.246862         21559.246862                 4
# 999     19965.750017         19965.750017                 4
#
#      Passed road safety
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ..                  ...
# 995                True
# 996                True
# 997                True
# 998                True
# 999                True
#
# [1000 rows x 11 columns]

# %%
car_sales = car_sales.drop("Total fuel used", axis = 1)

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0     honda  White        35431.0    4.0  15323.0    5.0        6.105188
# 1       bmw   Blue       192714.0    5.0  19943.0    5.0        9.314392
# 2     honda  White        84714.0    4.0  28343.0    5.0        7.549864
# 3    toyota  White       154365.0    4.0  13434.0    5.0        5.778420
# 4    nissan   Blue       181577.0    3.0  14043.0    5.0        6.412303
# ..      ...    ...            ...    ...      ...    ...             ...
# 995  toyota  Black        35820.0    4.0  32042.0    5.0        8.415605
# 996     NaN  White       155144.0    3.0   5716.0    5.0        5.955185
# 997  nissan   Blue        66604.0    4.0  31570.0    5.0        8.494556
# 998   honda  White       215883.0    4.0   4001.0    5.0        9.986542
# 999  toyota   Blue       248360.0    4.0  12732.0    5.0        8.039036
#
#      Number of wheels  Passed road safety
# 0                   4                True
# 1                   4                True
# 2                   4                True
# 3                   4                True
# 4                   4                True
# ..                ...                 ...
# 995                 4                True
# 996                 4                True
# 997                 4                True
# 998                 4                True
# 999                 4                True
#
# [1000 rows x 9 columns]

# %%
car_sales_shuffled = car_sales.sample(frac=0.02)

# %%
car_sales_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 807  toyota  Green        88519.0    4.0  18640.0    5.0        5.110720
# 777   honda   Blue       190532.0    4.0   8479.0    5.0        5.813625
# 326  toyota   Blue       232912.0    4.0   6029.0    5.0        6.315265
# 965   honda   Blue       168261.0    4.0  14691.0    5.0        6.213721
# 433   honda    Red       169579.0    NaN   8089.0    5.0        7.879894
# 663   honda    NaN        41846.0    4.0  10241.0    5.0        6.882969
# 734  toyota  White       235792.0    4.0  10726.0    5.0        7.917880
# 108  nissan   Blue       129769.0    3.0  15617.0    5.0        8.559434
# 743   honda    Red        47404.0    4.0  23554.0    5.0        8.610864
# 798     NaN   Blue        48777.0    4.0   7910.0    5.0        9.594067
# 664     bmw    Red        38775.0    5.0      NaN    5.0        7.915769
# 813  toyota  White        10247.0    4.0  32566.0    5.0        8.826677
# 462  toyota  Black        58773.0    4.0  20893.0    5.0        5.052693
# 103   honda  White       195787.0    4.0   5316.0    5.0        9.447845
# 162   honda  White       100527.0    4.0  22616.0    5.0        6.791424
# 682     bmw  Black        54141.0    5.0  37518.0    5.0        9.652377
# 298  toyota   Blue        44815.0    4.0   8460.0    5.0        7.595943
# 583  toyota  White            NaN    4.0  20521.0    5.0        5.887518
# 851  toyota  White        74984.0    4.0  16766.0    5.0        6.976303
# 562  toyota  White            NaN    4.0  14021.0    5.0        8.536551
#
#      Number of wheels  Passed road safety
# 807                 4                True
# 777                 4                True
# 326                 4                True
# 965                 4                True
# 433                 4                True
# 663                 4                True
# 734                 4                True
# 108                 4                True
# 743                 4                True
# 798                 4                True
# 664                 4                True
# 813                 4                True
# 462                 4                True
# 103                 4                True
# 162                 4                True
# 682                 4                True
# 298                 4                True
# 583                 4                True
# 851                 4                True
# 562                 4                True

# %%
car_sales_shuffled = car_sales_shuffled.reset_index(drop = True)

# %%
car_sales_shuffled["Odometer (KM)"] = car_sales_shuffled["Odometer (KM)"].apply(lambda x:x /1.6)

# %%
car_sales_shuffled
# Out:
#       Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0   toyota  Green      55324.375    4.0  18640.0    5.0        5.110720
# 1    honda   Blue     119082.500    4.0   8479.0    5.0        5.813625
# 2   toyota   Blue     145570.000    4.0   6029.0    5.0        6.315265
# 3    honda   Blue     105163.125    4.0  14691.0    5.0        6.213721
# 4    honda    Red     105986.875    NaN   8089.0    5.0        7.879894
# 5    honda    NaN      26153.750    4.0  10241.0    5.0        6.882969
# 6   toyota  White     147370.000    4.0  10726.0    5.0        7.917880
# 7   nissan   Blue      81105.625    3.0  15617.0    5.0        8.559434
# 8    honda    Red      29627.500    4.0  23554.0    5.0        8.610864
# 9      NaN   Blue      30485.625    4.0   7910.0    5.0        9.594067
# 10     bmw    Red      24234.375    5.0      NaN    5.0        7.915769
# 11  toyota  White       6404.375    4.0  32566.0    5.0        8.826677
# 12  toyota  Black      36733.125    4.0  20893.0    5.0        5.052693
# 13   honda  White     122366.875    4.0   5316.0    5.0        9.447845
# 14   honda  White      62829.375    4.0  22616.0    5.0        6.791424
# 15     bmw  Black      33838.125    5.0  37518.0    5.0        9.652377
# 16  toyota   Blue      28009.375    4.0   8460.0    5.0        7.595943
# 17  toyota  White            NaN    4.0  20521.0    5.0        5.887518
# 18  toyota  White      46865.000    4.0  16766.0    5.0        6.976303
# 19  toyota  White            NaN    4.0  14021.0    5.0        8.536551
#
#     Number of wheels  Passed road safety
# 0                  4                True
# 1                  4                True
# 2                  4                True
# 3                  4                True
# 4                  4                True
# 5                  4                True
# 6                  4                True
# 7                  4                True
# 8                  4                True
# 9                  4                True
# 10                 4                True
# 11                 4                True
# 12                 4                True
# 13                 4                True
# 14                 4                True
# 15                 4                True
# 16                 4                True
# 17                 4                True
# 18                 4                True
# 19                 4                True
